# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel(r"IC_data.xlsx", sheet_name=None)
columns = ['time', '415nm', '445nm', '480nm', '515nm', 'Clear', 'NIR', '555nm', '590nm', '630nm', '680nm', 'Clear.1', 'NIR.1']

# %%
print(f"Received following data:")
for sheet in data:
    data[sheet] = data[sheet][columns]
    display(data[sheet])
# Out:
# Received following data:
#        time  415nm  445nm  480nm  515nm  Clear   NIR  555nm  590nm  630nm  \
# 0      0.00   1703  19196  20241  23631  65535  5442  18919  28318  20386
# 1      0.66   1685  18970  20079  23678  65535  5439  19717  28633  20423
# 2      1.32   1736  15827  17263  27566  65535  6052  28972  36114  25539
# 3      1.99   1851  15779  17128  29176  65535  6028  31355  37151  25768
# 4      2.65   1937  15842  17258  30477  65535  6106  33640  38931  26827
# ..      ...    ...    ...    ...    ...    ...   ...    ...    ...    ...
# 264  175.15   3321  16937  22442  43514  65535  8542  48707  58907  50546
# 265  175.81   3321  16932  22430  43510  65535  8540  48715  58910  50555
# 266  176.47   3325  16934  22448  43517  65535  8544  48721  58912  50535
# 267  177.13   3322  16925  22444  43516  65535  8544  48762  58920  50563
# 268  177.80   3324  16932  22447  43529  65535  8546  48731  58915  50552
#
#      680nm  Clear.1  NIR.1
# ...

# %%
data['k5b'].columns
# Out:
# Index(['time', '415nm', '445nm', '480nm', '515nm', 'Clear', 'NIR', '555nm',
#        '590nm', '630nm', '680nm', 'Clear.1', 'NIR.1'],
#       dtype='object')
